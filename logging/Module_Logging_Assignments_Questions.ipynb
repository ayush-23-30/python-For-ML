# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.
#
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.
# 2. Modify the function to use different logging levels for the file and console handlers.
#
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.
# 2. Modify the function to use different formats for the file and console handlers.
#
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.
# 2. Modify the function to keep a specified number of backup log files.
#
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.
# 2. Modify the function to log the stack trace at the ERROR level.
#
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).
#
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.
# 2. Modify the dictionary to include different logging levels and formats for each handler.
#
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.
#
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).
# 2. Modify the script to compare the performance of logging with and without message formatting.
#
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
import logging 

def basic_logger():
  logging.basicConfig(
    filename='prac.log', 
    level=logging.DEBUG
  )

  logging.debug('this is a debug message')
  logging.info('this is a info message')
  logging.warning('this is a warning message')
  logging.error('this is a error message')
  logging.critical('this is a critical message')

  basic_logger()

# %%
def logger_with_handlers():
  logger = logging.getLogger('my_logger')
  logger.setLevel(logging.DEBUG)

  file_handler = logging.FileHandler('prac.log')
  console_handler = logging.StreamHandler()

  file_handler.setLevel(logging.DEBUG)
  console_handler.setLevel(logging.DEBUG)

  formatter = logging.Formatter('%(asctime)s - %(name)s -%(levelname)s - %(message)s')
  file_handler.setFormatter(formatter)
  console_handler.setFormatter(formatter)

  logger.addHandler(file_handler)
  logger.addHandler(console_handler)

  
  logging.debug('this is a debug message')
  logging.info('this is a info message')
  logging.warning('this is a warning message')
  logging.error('this is a error message')
  logging.critical('this is a critical message')

logger_with_handlers();
# Out:
# WARNING:root:this is a warning message
# ERROR:root:this is a error message
# CRITICAL:root:this is a critical message

# %%
def logger_with_custom_format():
  logger = logging.getLogger('custom_logger')
  logger.setLevel(logging.DEBUG)

  file_handler = logging.FileHandler('custom_app.log')
  console_handler = logging.StreamHandler()

  formatter = logging.Formatter('%(asctime)s - %(name)s -%(levelname)s - %(message)s')

  file_handler.setFormatter(formatter)
  console_handler.setFormatter(formatter)

  logger.addHandler(file_handler)
  logger.addHandler(console_handler)

  logger.debug('This is a debug message')
  logger.info('This is an info message')
  logger.warning('This is a warning message')
  logger.error('This is an error message')
  logger.critical('This is a critical message')

logger_with_custom_format()
# Out:
# 2025-05-09 14:03:36,644 - custom_logger -DEBUG - This is a debug message
# DEBUG:custom_logger:This is a debug message
# 2025-05-09 14:03:36,644 - custom_logger -INFO - This is an info message
# INFO:custom_logger:This is an info message
# 2025-05-09 14:03:36,644 - custom_logger -WARNING - This is a warning message
# WARNING:custom_logger:This is a warning message
# 2025-05-09 14:03:36,648 - custom_logger -ERROR - This is an error message
# ERROR:custom_logger:This is an error message
# 2025-05-09 14:03:36,649 - custom_logger -CRITICAL - This is a critical message
# CRITICAL:custom_logger:This is a critical message

# %%
def logger_with_different_format():
  logger = logging.getLogger('multi_format_logger')
  logger.setLevel(logging.DEBUG)

  file_handler = logging.FileHandler('multi_format_app.log')
  console_handler = logging.StreamHandler()

  formatter = logging.Formatter('%(asctime)s - %(name)s -%(levelname)s - %(message)s')

  file_handler.setFormatter(formatter)
  console_handler.setFormatter(formatter)

  logger.addHandler(file_handler)
  logger.addHandler(console_handler)

  logger.debug('This is a debug message')
  logger.info('This is an info message')
  logger.warning('This is a warning message')
  logger.error('This is an error message')
  logger.critical('This is a critical message')

logger_with_different_format()
# Out:
# 2025-05-09 14:04:46,219 - multi_format_logger -DEBUG - This is a debug message
# DEBUG:multi_format_logger:This is a debug message
# 2025-05-09 14:04:46,221 - multi_format_logger -INFO - This is an info message
# INFO:multi_format_logger:This is an info message
# 2025-05-09 14:04:46,221 - multi_format_logger -WARNING - This is a warning message
# WARNING:multi_format_logger:This is a warning message
# 2025-05-09 14:04:46,221 - multi_format_logger -ERROR - This is an error message
# ERROR:multi_format_logger:This is an error message
# 2025-05-09 14:04:46,221 - multi_format_logger -CRITICAL - This is a critical message
# CRITICAL:multi_format_logger:This is a critical message

# %%
from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
  logger = logging.getLogger('rotating_logger')
  logger.setLevel(logging.DEBUG)

  rotating_handler = RotatingFileHandler('rotating_app.log',maxBytes= 2000, backupCount=5)
  formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
  rotating_handler.setFormatter(formatter)

  logger.addHandler(rotating_handler)

  for i in range(100):
    logger.debug('This is debug message number {} '.format(i))

logger_with_rotating_file_handler()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 0 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 0 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 0 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 0
# DEBUG:rotating_logger:This is debug message number 1
# DEBUG:rotating_logger:This is debug message number 2
# DEBUG:rotating_logger:This is debug message number 3
# DEBUG:rotating_logger:This is debug message number 4
# DEBUG:rotating_logger:This is debug message number 5
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 6 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 6 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 6
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 7 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 7
# DEBUG:rotating_logger:This is debug message number 8
# DEBUG:rotating_logger:This is debug message number 9
# DEBUG:rotating_logger:This is debug message number 10
# DEBUG:rotating_logger:This is debug message number 11
# DEBUG:rotating_logger:This is debug message number 12
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 13 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 13 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 13 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 13
# DEBUG:rotating_logger:This is debug message number 14
# DEBUG:rotating_logger:This is debug message number 15
# DEBUG:rotating_logger:This is debug message number 16
# DEBUG:rotating_logger:This is debug message number 17
# DEBUG:rotating_logger:This is debug message number 18
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 19 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 19 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 19
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
# ...
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 91 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 91
# DEBUG:rotating_logger:This is debug message number 92
# DEBUG:rotating_logger:This is debug message number 93
# DEBUG:rotating_logger:This is debug message number 94
# DEBUG:rotating_logger:This is debug message number 95
# DEBUG:rotating_logger:This is debug message number 96
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 97 '
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 97 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 97
# --- Logging error ---
# Traceback (most recent call last):
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 74, in emit
#     self.doRollover()
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 179, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "d:\machine learning\python\venv\Lib\logging\handlers.py", line 115, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\machine learning\\python\\logging\\rotating_app.log' -> 'd:\\machine learning\\python\\logging\\rotating_app.log.1'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\machine learning\python\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\machine learning\python\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 618, in run_forever
#     self._run_once()
#   File "d:\machine learning\python\venv\Lib\asyncio\base_events.py", line 1951, in _run_once
#     handle._run()
#   File "d:\machine learning\python\venv\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\machine learning\python\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 16, in <module>
#     logger_with_rotating_file_handler()
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1566020088.py", line 14, in logger_with_rotating_file_handler
#     logger.debug('This is debug message number {} '.format(i))
# Message: 'This is debug message number 98 '
# Arguments: ()
# DEBUG:rotating_logger:This is debug message number 98
# DEBUG:rotating_logger:This is debug message number 99

# %%
def log_exception():
  logger = logging.getLogger('exception_logger')
  logger.setLevel(logging.ERROR)

  file_handler = logging.FileHandler('exception_app.log')
  formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
  file_handler.setFormatter(formatter)

  logger.addHandler(file_handler)

  try: 1/0
  except Exception as e:
    logger.exception ('An error occurred')


log_exception()
# Out:
# ERROR:exception_logger:An error occurred
# Traceback (most recent call last):
#   File "C:\Users\pawar\AppData\Local\Temp\ipykernel_14408\1009441223.py", line 11, in log_exception
#     try: 1/0
#          ~^~
# ZeroDivisionError: division by zero
